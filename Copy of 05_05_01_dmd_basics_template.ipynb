# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Define the functions
def f1(xx, tt):
    y_1 = 2 * np.cos(xx) * np.exp(1j * tt)
    return y_1

def f2(xx, tt):
    y_2 = np.sin(xx) * np.exp(3j * tt)
    return y_2

# %%
#Define time and space discretizations
xi = np.linspace(-10, 10, 400)
t = np.linspace(0, 4*np.pi, 201)
dt = t[1] - t[0]
xx, tt = np.meshgrid(xi, t)
X = f1(xx, tt) + f2(xx, tt)

# %%
plt.figure(figsize=(4, 4))
plt.contourf(xx, tt, np.real(X), 20, cmap='RdGy')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('t')
plt.title('Contour plot of X')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.contourf(tt.T, xx.T, np.real(X.T), 20, cmap='RdGy')
plt.colorbar()
plt.xlabel('t')
plt.ylabel('x')
plt.title('Contour plot of X')
plt.show()

# %%
X_1 = X.T[:, :-1]
X_2 = X.T[:, 1:]
print(X_1.shape)
# Out:
# (400, 200)

# %%
# Step 1 - SVD
U, Sigma, V = np.linalg.svd(X_1,full_matrices=False)
print(U.shape,Sigma.shape, V.shape)
# Out:
# (400, 200) (200,) (200, 200)

# %%
plt.figure(figsize=(4, 4))
plt.plot(U[:, 0], label='U[:, 0]')
plt.plot(U[:, 1], label='U[:, 1]')
#plt.plot(U[:, 2], label='U[:, 2]')
#plt.plot(U[:, 3], label='U[:, 3]')
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4, 4))
plt.plot(Sigma[:10], 'o-')
plt.xlabel('Index')
plt.ylabel('Singular Value')
plt.title('First 10 Singular Values of X')
plt.show()

# %%
print(Sigma[:4])
# Out:
# [4.09197304e+02 1.95293092e+02 1.71219345e-13 9.77353812e-14]

# %%
plt.figure(figsize=(4, 4))
plt.plot(V[0,:], label='V[0,:]')
plt.plot(V[1,:], label='V[1,:]')
#plt.plot(V[2,:], label='V[2,:]')
#plt.plot(V[3,:], label='V[3,:]')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Take only the first two modes**

# %%
U, Sigma, V = U[:, :2], Sigma[:2], V[:2, :]
print(U.shape, np.diag(Sigma).shape, V.shape)
# Out:
# (400, 2) (2, 2) (2, 200)

# %%
print(X_2.shape)
# Out:
# (400, 200)

# %%
print(U[:2,:2])
# Out:
# [[-0.05799776+7.11886290e-17j  0.03939525+1.58365802e-16j]
#  [-0.05980901+2.55676730e-16j  0.03630137-5.04967735e-16j]]

# %%
A_tilde = np.linalg.multi_dot([U.conj().T, X_2, V.conj().T, np.linalg.inv(np.diag(Sigma))])
Lambda, W = np.linalg.eig(A_tilde)
print(A_tilde.shape)
print(A_tilde)
# Out:
# (2, 2)
# [[ 9.98026728e-01+6.27905195e-02j -2.32878447e-16+1.62731844e-16j]
#  [-7.12324960e-17-6.29003852e-18j  9.82287251e-01+1.87381315e-01j]]

# %%
Phi = np.linalg.multi_dot([X_2, V.conj().T, np.linalg.inv(np.diag(Sigma)), W])

# %%
plt.figure(figsize=(4, 4))
plt.plot(xi, Phi[:, 0], '-', label='Phi_1')
plt.plot(xi, Phi[:, 1], '-', label='Phi_2')
plt.xlabel('x')
plt.ylabel('Phi')
plt.legend()
plt.title('First Two POD Modes')
plt.show()

# %%
b, residuals, rank, sigma = np.linalg.lstsq(Phi, X_1[:,0], rcond=None)
print(b.shape)
print(b)
# Out:
# (2,)
# [28.87752297-1.81681975j 13.56470615-2.58760609j]

# %%
Omega = np.log(Lambda)/dt
print(Omega.shape)
# Out:
# (2,)

# %%
t_exp = np.arange(X.T.shape[1]) * dt
temp = np.repeat(Omega.reshape(-1,1), t_exp.size, axis=1)
dynamics = np.exp(temp * t_exp) * b.reshape(2, -1)
#plt.plot(t_exp)
print(temp.shape)
#plt.plot(temp[0,:])
# Out:
# (2, 201)

# %%
plt.figure(figsize=(4, 4))
plt.plot(t_exp, dynamics[0, :], '-', label='b_1')
plt.plot(t_exp, dynamics[1, :], '-', label='b_2')
plt.xlabel('t')
plt.ylabel('Dynamics')
plt.legend()
plt.title('Dynamics of the reduced model')
plt.show()

# %%
X_dmd = Phi @ dynamics

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 3, 1)
plt.contourf(xx, tt, np.real(X), 20, cmap='RdGy')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('t')
plt.title('Contour plot of X')

plt.subplot(1, 3, 2)
plt.contourf(xx, tt, np.real(X_dmd.T), 20, cmap='RdGy')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('t')
plt.title('Contour plot of X_dmd')

plt.subplot(1, 3, 3)
plt.contourf(xx, tt, np.real(X) - np.real(X_dmd.T), 20, cmap='RdGy')
plt.colorbar()
plt.xlabel('x')
plt.ylabel('t')
plt.title('Contour plot of Residual')

plt.show()

print('norm of error: ', np.linalg.norm(np.real(X) - np.real(X_dmd.T)))
print('norm of reference: ', np.linalg.norm(np.real(X)))
# Out:
# norm of error:  1.546470434786553e-11
# norm of reference:  322.20928234680065
